# %%
# Cell 1
import sqlite3
import pandas as pd

def query_db(sql_query, db_path='employees.db'):
    """Execute SQL query and return results as DataFrame"""
    conn = sqlite3.connect(db_path)
    try:
        result = pd.read_sql_query(sql_query, conn)
        return result
    except Exception as e:
        print(f"Error: {e}")
        return None
    finally:
        conn.close()

# Cell 2 - Test it
query_db("SELECT COUNT(*) as total_employees FROM employees")

# Cell 3 - Interactive queries
query_db("""
SELECT d.department_name, COUNT(e.employee_id) as headcount
FROM departments d
LEFT JOIN employees e ON d.department_id = e.department_id
GROUP BY d.department_name
ORDER BY headcount DESC
""")
# Out:
#   department_name  headcount
# 0     Engineering        112
# 1           Sales        111
# 2       Marketing        111
# 3       Executive         90
# 4      Operations         76

# %%
query_db("""
SELECT reportsto, 
         COUNT(employee_id) as headcount, 
         avg(age) as avg_age
FROM employees
         where reportsto is not null
GROUP BY 1
ORDER BY 1
""")
# Out:
#      reportsto  headcount    avg_age
# 0            1         75  44.480000
# 1            2          6  48.666667
# 2            5          7  44.714286
# 3            6          6  42.500000
# 4           10          4  42.500000
# ..         ...        ...        ...
# 136        450          2  28.500000
# 137        459          1  31.000000
# 138        463          1  56.000000
# 139        465          2  44.500000
# 140        486          1  57.000000
#
# [141 rows x 3 columns]

# %%
query_db("""select * from employees limit 3""")
# Out:
#    employee_id firstname  lastname  reportsto        position  age  \
# 0            1      Tony  Buchanan        1.0    Data Analyst   60
# 1            2   Jessica  Espinoza        1.0  VP Engineering   50
# 2            3    Walter   Goodwin        NaN             CEO   36
#
#    department_id     salary   hire_date
# 0              5   47966.56  2017-08-04
# 1              1  115811.38  2022-03-06
# 2              1  218526.25  2019-01-04

# %%
query_db("""
SELECT firstname,
         lastname,
         reportsto, 
         position, 
         age,
         case when reportsto is null then 'None' else 'CEO' end
FROM employees
         where reportsto in (Null, 1)
GROUP BY 1
ORDER BY 1
""")
# Out:
#     firstname  lastname  reportsto         position  age  \
# 0   Alexander     Huynh          1  Junior Engineer   64
# 1      Amanda     Black          1     VP Marketing   63
# 2       Amber    Thomas          1     VP Marketing   30
# 3      Andrew    Dawson          1   VP Engineering   50
# 4         Ann   Shields          1     VP Marketing   46
# ..        ...       ...        ...              ...  ...
# 58      Tommy    Bishop          1   VP Engineering   33
# 59       Tony  Buchanan          1     Data Analyst   60
# 60    Vincent    Henson          1         VP Sales   54
# 61      Wendy    Martin          1   VP Engineering   37
# 62    Zachary      Reed          1     VP Marketing   48
#
#    case when reportsto is null then 'None' else 'CEO' end
# 0                                                 CEO
# 1                                                 CEO
# 2                                                 CEO
# 3                                                 CEO
# 4                                                 CEO
# ..                                                ...
# 58                                                CEO
# 59                                                CEO
# 60                                                CEO
# 61                                                CEO
# 62                                                CEO
#
# [63 rows x 6 columns]

# %% [markdown]
# * 🔢 ROW_NUMBER()
# - Assigns unique sequential numbers to each row
# - No ties - every row gets a different number
# - Sequential - 1, 2, 3, 4, 5, 6...
# * 🏆 RANK()
# - Assigns ranks with gaps when there are ties
# - Handles ties by giving them the same rank
# - Skips numbers after ties - 1, 2, 2, 4, 5, 6...
# * 🥇 DENSE_RANK()
# - Assigns ranks without gaps when there are ties
# - Handles ties by giving them the same rank
# - No skipped numbers - 1, 2, 2, 3, 4, 5...

# %%
# ROW_NUMBER() - Assigns unique sequential numbers to rows
print("🔢 ROW_NUMBER() Example:")
print("Ranking employees by salary with unique row numbers")
query_db("""
SELECT 
    firstname || ' ' || lastname AS employee_name,
    position,
    salary,
    ROW_NUMBER() OVER (ORDER BY salary DESC) AS salary_row_number
FROM employees 
WHERE salary IS NOT NULL
ORDER BY salary DESC
LIMIT 15
""")
# Out:
# 🔢 ROW_NUMBER() Example:
# Ranking employees by salary with unique row numbers
#       employee_name      position     salary  salary_row_number
# 0    Beth Frederick           CEO  310246.15                  1
# 1   Theodore Rivera           CEO  293837.73                  2
# 2   Karen Rodriguez           CEO  287017.04                  3
# 3        Kyle Berry           CEO  277478.82                  4
# 4      Larry Lawson           CEO  264551.70                  5
# 5    Debbie Wallace           CEO  260379.91                  6
# 6       Andrew Gray           CEO  254623.94                  7
# 7    Stephanie Reid           CEO  252717.53                  8
# 8    Robert Hartman  VP Marketing  250439.91                  9
# 9    Amanda Skinner           CEO  250196.87                 10
# 10     Nicole Brown           CEO  249264.09                 11
# 11   Vincent Henson      VP Sales  248272.84                 12
# 12   Donald Hartman           CEO  244902.52                 13
# 13      Sean Miller           CEO  242113.80                 14
# 14   Kimberly Evans  VP Marketing  241652.78                 15

# %%
# RANK() - Assigns ranks with gaps for ties
print("🏆 RANK() Example:")
print("Ranking employees by salary (with gaps for ties)")
query_db("""
SELECT 
    firstname || ' ' || lastname AS employee_name,
    position,
    salary,
    RANK() OVER (ORDER BY salary DESC) AS salary_rank
FROM employees 
WHERE salary IS NOT NULL
ORDER BY salary DESC
LIMIT 15
""")
# Out:
# 🏆 RANK() Example:
# Ranking employees by salary (with gaps for ties)
#       employee_name      position     salary  salary_rank
# 0    Beth Frederick           CEO  310246.15            1
# 1   Theodore Rivera           CEO  293837.73            2
# 2   Karen Rodriguez           CEO  287017.04            3
# 3        Kyle Berry           CEO  277478.82            4
# 4      Larry Lawson           CEO  264551.70            5
# 5    Debbie Wallace           CEO  260379.91            6
# 6       Andrew Gray           CEO  254623.94            7
# 7    Stephanie Reid           CEO  252717.53            8
# 8    Robert Hartman  VP Marketing  250439.91            9
# 9    Amanda Skinner           CEO  250196.87           10
# 10     Nicole Brown           CEO  249264.09           11
# 11   Vincent Henson      VP Sales  248272.84           12
# 12   Donald Hartman           CEO  244902.52           13
# 13      Sean Miller           CEO  242113.80           14
# 14   Kimberly Evans  VP Marketing  241652.78           15

# %%
# DENSE_RANK() - Assigns ranks without gaps for ties
print("🥇 DENSE_RANK() Example:")
print("Dense ranking by salary (no gaps for ties)")
query_db("""
SELECT 
    firstname || ' ' || lastname AS employee_name,
    position,
    salary,
    DENSE_RANK() OVER (ORDER BY salary DESC) AS dense_salary_rank
FROM employees 
WHERE salary IS NOT NULL
ORDER BY salary DESC
LIMIT 15
""")
# Out:
# 🥇 DENSE_RANK() Example:
# Dense ranking by salary (no gaps for ties)
#       employee_name      position     salary  dense_salary_rank
# 0    Beth Frederick           CEO  310246.15                  1
# 1   Theodore Rivera           CEO  293837.73                  2
# 2   Karen Rodriguez           CEO  287017.04                  3
# 3        Kyle Berry           CEO  277478.82                  4
# 4      Larry Lawson           CEO  264551.70                  5
# 5    Debbie Wallace           CEO  260379.91                  6
# 6       Andrew Gray           CEO  254623.94                  7
# 7    Stephanie Reid           CEO  252717.53                  8
# 8    Robert Hartman  VP Marketing  250439.91                  9
# 9    Amanda Skinner           CEO  250196.87                 10
# 10     Nicole Brown           CEO  249264.09                 11
# 11   Vincent Henson      VP Sales  248272.84                 12
# 12   Donald Hartman           CEO  244902.52                 13
# 13      Sean Miller           CEO  242113.80                 14
# 14   Kimberly Evans  VP Marketing  241652.78                 15

# %%
# PARTITION BY - Ranking within groups
print("🏢 PARTITION BY Example:")
print("Ranking employees by salary within each department")
query_db("""
SELECT 
    d.department_name,
    e.firstname || ' ' || e.lastname AS employee_name,
    e.position,
    e.salary,
    ROW_NUMBER() OVER (PARTITION BY d.department_name ORDER BY e.salary DESC) AS dept_rank
FROM employees e
JOIN departments d ON e.department_id = d.department_id
WHERE e.salary IS NOT NULL
ORDER BY d.department_name, dept_rank
""")
# Out:
# 🏢 PARTITION BY Example:
# Ranking employees by salary within each department
#     department_name    employee_name              position     salary  \
# 0       Engineering    Bernard Floyd   Director Operations  181189.76
# 1       Engineering   Shannon Cortez  Director Engineering  180783.25
# 2       Engineering   Albert Jimenez  Director Engineering  160324.67
# 3       Engineering     Wendy Becker  Director Engineering  157437.24
# 4       Engineering    Xavier Garcia  Director Engineering  155987.94
# ..              ...              ...                   ...        ...
# 495           Sales     Marc Hickman      Junior Sales Rep   40543.90
# 496           Sales  Victor Martinez      Junior Sales Rep   38877.73
# 497           Sales   Mikayla Carter             Sales Rep   38308.68
# 498           Sales  Maria Rodriguez      Junior Sales Rep   38264.95
# 499           Sales      Blake Woods             Sales Rep   37691.27
#
#      dept_rank
# 0            1
# 1            2
# 2            3
# 3            4
# 4            5
# ..         ...
# 495        107
# 496        108
# 497        109
# 498        110
# 499        111
#
# [500 rows x 5 columns]

# %%
# NTILE() - Divides rows into buckets/quartiles
print("📊 NTILE() Example:")
print("Dividing employees into salary quartiles (4 buckets)")
query_db("""
SELECT 
    firstname || ' ' || lastname AS employee_name,
    position,
    salary,
    NTILE(4) OVER (ORDER BY salary) AS salary_quartile,
    CASE 
        WHEN NTILE(4) OVER (ORDER BY salary) = 1 THEN 'Bottom 25%'
        WHEN NTILE(4) OVER (ORDER BY salary) = 2 THEN 'Lower Middle 25%'
        WHEN NTILE(4) OVER (ORDER BY salary) = 3 THEN 'Upper Middle 25%'
        WHEN NTILE(4) OVER (ORDER BY salary) = 4 THEN 'Top 25%'
    END AS quartile_description
FROM employees 
WHERE salary IS NOT NULL
ORDER BY salary DESC
LIMIT 20
""")
# Out:
# 📊 NTILE() Example:
# Dividing employees into salary quartiles (4 buckets)
#       employee_name        position     salary  salary_quartile  \
# 0    Beth Frederick             CEO  310246.15                4
# 1   Theodore Rivera             CEO  293837.73                4
# 2   Karen Rodriguez             CEO  287017.04                4
# 3        Kyle Berry             CEO  277478.82                4
# 4      Larry Lawson             CEO  264551.70                4
# 5    Debbie Wallace             CEO  260379.91                4
# 6       Andrew Gray             CEO  254623.94                4
# 7    Stephanie Reid             CEO  252717.53                4
# 8    Robert Hartman    VP Marketing  250439.91                4
# 9    Amanda Skinner             CEO  250196.87                4
# 10     Nicole Brown             CEO  249264.09                4
# 11   Vincent Henson        VP Sales  248272.84                4
# 12   Donald Hartman             CEO  244902.52                4
# 13      Sean Miller             CEO  242113.80                4
# 14   Kimberly Evans    VP Marketing  241652.78                4
# 15      Stacey Bell             CEO  236545.28                4
# 16   Richard Stokes    VP Marketing  235302.41                4
# 17     Miguel Smith             CEO  233287.65                4
# 18     Tommy Bishop  VP Engineering  225713.62                4
# 19      Derek Vance             CEO  223317.56                4
#
#    quartile_description
# 0               Top 25%
# 1               Top 25%
# 2               Top 25%
# 3               Top 25%
# 4               Top 25%
# 5               Top 25%
# 6               Top 25%
# 7               Top 25%
# 8               Top 25%
# 9               Top 25%
# 10              Top 25%
# 11              Top 25%
# 12              Top 25%
# 13              Top 25%
# 14              Top 25%
# 15              Top 25%
# 16              Top 25%
# 17              Top 25%
# 18              Top 25%
# 19              Top 25%

# %%
# LAG() - Access previous row values
print("⬅️ LAG() Example:")
print("Compare each employee's salary to the previous employee's salary")
query_db("""
SELECT 
    firstname || ' ' || lastname AS employee_name,
    position,
    salary,
    LAG(salary, 1) OVER (ORDER BY salary DESC) AS previous_salary,
    salary - LAG(salary, 1) OVER (ORDER BY salary DESC) AS salary_difference
FROM employees 
WHERE salary IS NOT NULL
ORDER BY salary DESC
LIMIT 15
""")
# Out:
# ⬅️ LAG() Example:
# Compare each employee's salary to the previous employee's salary
#       employee_name      position     salary  previous_salary  \
# 0    Beth Frederick           CEO  310246.15              NaN
# 1   Theodore Rivera           CEO  293837.73        310246.15
# 2   Karen Rodriguez           CEO  287017.04        293837.73
# 3        Kyle Berry           CEO  277478.82        287017.04
# 4      Larry Lawson           CEO  264551.70        277478.82
# 5    Debbie Wallace           CEO  260379.91        264551.70
# 6       Andrew Gray           CEO  254623.94        260379.91
# 7    Stephanie Reid           CEO  252717.53        254623.94
# 8    Robert Hartman  VP Marketing  250439.91        252717.53
# 9    Amanda Skinner           CEO  250196.87        250439.91
# 10     Nicole Brown           CEO  249264.09        250196.87
# 11   Vincent Henson      VP Sales  248272.84        249264.09
# 12   Donald Hartman           CEO  244902.52        248272.84
# 13      Sean Miller           CEO  242113.80        244902.52
# 14   Kimberly Evans  VP Marketing  241652.78        242113.80
#
#     salary_difference
# 0                 NaN
# 1           -16408.42
# 2            -6820.69
# 3            -9538.22
# 4           -12927.12
# 5            -4171.79
# 6            -5755.97
# 7            -1906.41
# 8            -2277.62
# 9             -243.04
# 10            -932.78
# 11            -991.25
# 12           -3370.32
# 13           -2788.72
# 14            -461.02

# %%
# LEAD() - Access next row values
print("➡️ LEAD() Example:")
print("Compare each employee's salary to the next employee's salary")
query_db("""
SELECT 
    firstname || ' ' || lastname AS employee_name,
    position,
    salary,
    LEAD(salary, 1) OVER (ORDER BY salary DESC) AS next_salary,
    salary - LEAD(salary, 1) OVER (ORDER BY salary DESC) AS salary_gap_to_next
FROM employees 
WHERE salary IS NOT NULL
ORDER BY salary DESC
LIMIT 15
""")
# Out:
# ➡️ LEAD() Example:
# Compare each employee's salary to the next employee's salary
#       employee_name      position     salary  next_salary  salary_gap_to_next
# 0    Beth Frederick           CEO  310246.15    293837.73            16408.42
# 1   Theodore Rivera           CEO  293837.73    287017.04             6820.69
# 2   Karen Rodriguez           CEO  287017.04    277478.82             9538.22
# 3        Kyle Berry           CEO  277478.82    264551.70            12927.12
# 4      Larry Lawson           CEO  264551.70    260379.91             4171.79
# 5    Debbie Wallace           CEO  260379.91    254623.94             5755.97
# 6       Andrew Gray           CEO  254623.94    252717.53             1906.41
# 7    Stephanie Reid           CEO  252717.53    250439.91             2277.62
# 8    Robert Hartman  VP Marketing  250439.91    250196.87              243.04
# 9    Amanda Skinner           CEO  250196.87    249264.09              932.78
# 10     Nicole Brown           CEO  249264.09    248272.84              991.25
# 11   Vincent Henson      VP Sales  248272.84    244902.52             3370.32
# 12   Donald Hartman           CEO  244902.52    242113.80             2788.72
# 13      Sean Miller           CEO  242113.80    241652.78              461.02
# 14   Kimberly Evans  VP Marketing  241652.78    236545.28             5107.50

# %%
# Complex example combining multiple window functions
print("🎯 COMPLEX WINDOW FUNCTIONS Example:")
print("Comprehensive salary analysis using multiple window functions")
query_db("""
SELECT 
    d.department_name,
    e.firstname || ' ' || e.lastname AS employee_name,
    e.position,
    e.salary,
    -- Ranking functions
    ROW_NUMBER() OVER (ORDER BY e.salary DESC) AS overall_rank,
    RANK() OVER (PARTITION BY d.department_name ORDER BY e.salary DESC) AS dept_rank,
    DENSE_RANK() OVER (ORDER BY e.salary DESC) AS dense_rank,
    -- Quartiles
    NTILE(4) OVER (ORDER BY e.salary) AS salary_quartile,
    -- Comparison to adjacent salaries
    LAG(e.salary, 1) OVER (ORDER BY e.salary DESC) AS prev_salary,
    LEAD(e.salary, 1) OVER (ORDER BY e.salary DESC) AS next_salary,
    -- Department statistics
    AVG(e.salary) OVER (PARTITION BY d.department_name) AS dept_avg_salary,
    MAX(e.salary) OVER (PARTITION BY d.department_name) AS dept_max_salary,
    MIN(e.salary) OVER (PARTITION BY d.department_name) AS dept_min_salary
FROM employees e
JOIN departments d ON e.department_id = d.department_id
WHERE e.salary IS NOT NULL
ORDER BY e.salary DESC
LIMIT 20
""")
# Out:
# 🎯 COMPLEX WINDOW FUNCTIONS Example:
# Comprehensive salary analysis using multiple window functions
#    department_name    employee_name        position     salary  overall_rank  \
# 0        Executive   Beth Frederick             CEO  310246.15             1
# 1        Executive  Theodore Rivera             CEO  293837.73             2
# 2        Executive  Karen Rodriguez             CEO  287017.04             3
# 3        Executive       Kyle Berry             CEO  277478.82             4
# 4        Executive     Larry Lawson             CEO  264551.70             5
# 5        Executive   Debbie Wallace             CEO  260379.91             6
# 6        Executive      Andrew Gray             CEO  254623.94             7
# 7        Executive   Stephanie Reid             CEO  252717.53             8
# 8        Executive   Robert Hartman    VP Marketing  250439.91             9
# 9        Executive   Amanda Skinner             CEO  250196.87            10
# 10       Executive     Nicole Brown             CEO  249264.09            11
# 11       Executive   Vincent Henson        VP Sales  248272.84            12
# 12       Executive   Donald Hartman             CEO  244902.52            13
# 13       Executive      Sean Miller             CEO  242113.80            14
# 14       Executive   Kimberly Evans    VP Marketing  241652.78            15
# 15       Executive      Stacey Bell             CEO  236545.28            16
# 16       Executive   Richard Stokes    VP Marketing  235302.41            17
# 17       Executive     Miguel Smith             CEO  233287.65            18
# 18       Executive     Tommy Bishop  VP Engineering  225713.62            19
# 19       Executive      Derek Vance             CEO  223317.56            20
#
#     dept_rank  dense_rank  salary_quartile  prev_salary  next_salary  \
# 0           1           1                4          NaN    293837.73
# 1           2           2                4    310246.15    287017.04
# 2           3           3                4    293837.73    277478.82
# 3           4           4                4    287017.04    264551.70
# 4           5           5                4    277478.82    260379.91
# 5           6           6                4    264551.70    254623.94
# 6           7           7                4    260379.91    252717.53
# 7           8           8                4    254623.94    250439.91
# 8           9           9                4    252717.53    250196.87
# 9          10          10                4    250439.91    249264.09
# 10         11          11                4    250196.87    248272.84
# 11         12          12                4    249264.09    244902.52
# 12         13          13                4    248272.84    242113.80
# 13         14          14                4    244902.52    241652.78
# 14         15          15                4    242113.80    236545.28
# 15         16          16                4    241652.78    235302.41
# 16         17          17                4    236545.28    233287.65
# 17         18          18                4    235302.41    225713.62
# 18         19          19                4    233287.65    223317.56
# 19         20          20                4    225713.62    221871.96
#
#     dept_avg_salary  dept_max_salary  dept_min_salary
# 0     195061.103556        310246.15        115811.38
# 1     195061.103556        310246.15        115811.38
# 2     195061.103556        310246.15        115811.38
# 3     195061.103556        310246.15        115811.38
# 4     195061.103556        310246.15        115811.38
# 5     195061.103556        310246.15        115811.38
# 6     195061.103556        310246.15        115811.38
# 7     195061.103556        310246.15        115811.38
# 8     195061.103556        310246.15        115811.38
# 9     195061.103556        310246.15        115811.38
# 10    195061.103556        310246.15        115811.38
# 11    195061.103556        310246.15        115811.38
# 12    195061.103556        310246.15        115811.38
# 13    195061.103556        310246.15        115811.38
# 14    195061.103556        310246.15        115811.38
# 15    195061.103556        310246.15        115811.38
# 16    195061.103556        310246.15        115811.38
# 17    195061.103556        310246.15        115811.38
# 18    195061.103556        310246.15        115811.38
# 19    195061.103556        310246.15        115811.38

# %%
# OVER clause with different ordering and partitioning
print("🔄 OVER Clause Variations:")
print("Different ways to use the OVER clause")
query_db("""
SELECT 
    d.department_name,
    e.firstname || ' ' || e.lastname AS employee_name,
    e.age,
    e.salary,
    -- Different OVER clause examples
    COUNT(*) OVER () AS total_employees,
    COUNT(*) OVER (PARTITION BY d.department_name) AS dept_employees,
    AVG(e.salary) OVER () AS company_avg_salary,
    AVG(e.salary) OVER (PARTITION BY d.department_name) AS dept_avg_salary,
    SUM(e.salary) OVER (ORDER BY e.salary ROWS BETWEEN UNBOUNDED PRECEDING AND CURRENT ROW) AS running_salary_total,
    ROW_NUMBER() OVER (PARTITION BY d.department_name ORDER BY e.age) AS age_rank_in_dept
FROM employees e
JOIN departments d ON e.department_id = d.department_id
WHERE e.salary IS NOT NULL
ORDER BY d.department_name, e.salary DESC
LIMIT 25
""")
# Out:
# 🔄 OVER Clause Variations:
# Different ways to use the OVER clause
#    department_name      employee_name  age     salary  total_employees  \
# 0      Engineering      Bernard Floyd   29  181189.76              500
# 1      Engineering     Shannon Cortez   53  180783.25              500
# 2      Engineering     Albert Jimenez   29  160324.67              500
# 3      Engineering       Wendy Becker   44  157437.24              500
# 4      Engineering      Xavier Garcia   58  155987.94              500
# 5      Engineering   William Phillips   36  154341.42              500
# 6      Engineering     Jonathon Adams   51  153814.55              500
# 7      Engineering       Lori Patrick   28  150960.39              500
# 8      Engineering      Jeffrey Jones   47  149670.09              500
# 9      Engineering         Heidi Pena   26  144947.36              500
# 10     Engineering   Stephen Williams   53  141590.09              500
# 11     Engineering       Heather Park   48  140759.20              500
# 12     Engineering  Christine Jackson   53  140709.84              500
# 13     Engineering        Sarah Scott   57  140291.78              500
# 14     Engineering          Paula Roy   30  138124.53              500
# 15     Engineering      Monique Moore   42  137884.66              500
# 16     Engineering        James White   35  136290.26              500
# 17     Engineering        Jade Mendez   43  135574.46              500
# 18     Engineering       James Morris   43  131537.90              500
# 19     Engineering     Anthony Hoover   64  128890.30              500
# 20     Engineering   Patricia Hopkins   50  127830.04              500
# 21     Engineering        James Smith   60  124819.43              500
# 22     Engineering    Whitney Roberts   48  120131.35              500
# 23     Engineering         Tara Baker   42  119096.62              500
# 24     Engineering     Jessica Garcia   35  117405.98              500
#
#     dept_employees  company_avg_salary  dept_avg_salary  running_salary_total  \
# 0              112        102191.38026     89328.469554           38756834.49
# 1              112        102191.38026     89328.469554           38575644.73
# 2              112        102191.38026     89328.469554           34357142.17
# 3              112        102191.38026     89328.469554           34196817.50
# 4              112        102191.38026     89328.469554           33726068.40
# 5              112        102191.38026     89328.469554           32949023.86
# 6              112        102191.38026     89328.469554           32640696.82
# 7              112        102191.38026     89328.469554           31726161.38
# 8              112        102191.38026     89328.469554           31124310.21
# 9              112        102191.38026     89328.469554           30386546.87
# 10             112        102191.38026     89328.469554           29809181.98
# 11             112        102191.38026     89328.469554           29526409.71
# 12             112        102191.38026     89328.469554           29385650.51
# 13             112        102191.38026     89328.469554           29244940.67
# 14             112        102191.38026     89328.469554           28685482.57
# 15             112        102191.38026     89328.469554           28547358.04
# 16             112        102191.38026     89328.469554           27998650.53
# 17             112        102191.38026     89328.469554           27862360.27
# 18             112        102191.38026     89328.469554           27057433.43
# 19             112        102191.38026     89328.469554           26406769.63
# 20             112        102191.38026     89328.469554           26149981.70
# 21             112        102191.38026     89328.469554           25138092.49
# 22             112        102191.38026     89328.469554           24527365.15
# 23             112        102191.38026     89328.469554           24407233.80
# 24             112        102191.38026     89328.469554           23815362.62
#
#     age_rank_in_dept
# 0                 20
# 1                 78
# 2                 22
# 3                 50
# 4                101
# 5                 32
# 6                 76
# 7                 18
# 8                 63
# 9                 12
# 10                87
# 11                68
# 12                85
# 13                98
# 14                23
# 15                42
# 16                28
# 17                48
# 18                46
# 19               112
# 20                74
# 21               104
# 22                67
# 23                45
# 24                30

# %%
# Performance analysis using window functions
print("⭐ Performance Analysis with Window Functions:")
print("Analyzing performance ratings using window functions")
query_db("""
SELECT 
    e.firstname || ' ' || e.lastname AS employee_name,
    d.department_name,
    pr.rating,
    pr.review_date,
    -- Performance ranking
    RANK() OVER (ORDER BY pr.rating DESC) AS performance_rank,
    DENSE_RANK() OVER (PARTITION BY d.department_name ORDER BY pr.rating DESC) AS dept_performance_rank,
    -- Performance quartiles
    NTILE(4) OVER (ORDER BY pr.rating DESC) AS performance_quartile,
    -- Comparison to others
    AVG(pr.rating) OVER () AS company_avg_rating,
    AVG(pr.rating) OVER (PARTITION BY d.department_name) AS dept_avg_rating,
    pr.rating - AVG(pr.rating) OVER (PARTITION BY d.department_name) AS rating_vs_dept_avg,
    -- Previous and next ratings
    LAG(pr.rating, 1) OVER (ORDER BY pr.rating DESC) AS prev_rating,
    LEAD(pr.rating, 1) OVER (ORDER BY pr.rating DESC) AS next_rating
FROM employees e
JOIN departments d ON e.department_id = d.department_id
JOIN performance_reviews pr ON e.employee_id = pr.employee_id
ORDER BY pr.rating DESC
LIMIT 30
""")

# %%
# Practice cell - Try your own window function queries
print("🧪 Practice Window Functions:")
print("Write your own window function queries here!")

my_query = """
-- Example: Find top 3 employees by salary in each department
SELECT 
    d.department_name,
    e.firstname || ' ' || e.lastname AS employee_name,
    e.salary,
    RANK() OVER (PARTITION BY d.department_name ORDER BY e.salary DESC) AS dept_salary_rank
FROM employees e
JOIN departments d ON e.department_id = d.department_id
WHERE e.salary IS NOT NULL
  AND RANK() OVER (PARTITION BY d.department_name ORDER BY e.salary DESC) <= 3
ORDER BY d.department_name, dept_salary_rank;
"""

# %%
# Practice Cell - GROUP BY and HAVING
print("🧪 Practice GROUP BY and HAVING:")
print("Try writing your own GROUP BY and HAVING queries!")

# Example template:
my_query = """
-- Template: Find [groups] where [conditions]
SELECT 
    -- grouping columns
    -- aggregate functions: COUNT(), AVG(), SUM(), MIN(), MAX()
FROM employees e
LEFT JOIN departments d ON e.department_id = d.department_id
WHERE -- row-level filters (before grouping)
GROUP BY -- columns to group by
HAVING -- group-level filters (after grouping)
ORDER BY -- sorting
"""

print("💡 Common HAVING use cases:")
print("• COUNT(*) > 5 (groups with more than 5 items)")
print("• AVG(salary) > 80000 (groups with high average)")
print("• MAX(salary) - MIN(salary) > 50000 (high variance)")
print("• SUM(salary) > 500000 (high total)")
